# %% [markdown]
# # Unsupervised ML -Agglomerative Clustering
# (Hierarchical Clustering)

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %%
# import dataset
Airlines=pd.read_csv('EastWestAirlines.csv')
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
Airlines.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
# Normalization[0to1]
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
df_norm=norm_func(Airlines.iloc[:,1:])

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Dendgrogram = sch.dendrogram(sch.linkage(df_norm, method='complete'))

# %%
hc=AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage = 'complete')

# %%
y_hc = hc.fit_predict(df_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
Clusters
# Out:
#       Clusters
# 0            2
# 1            2
# 2            2
# 3            2
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         2
# 3998         2
#
# [3999 rows x 1 columns]

# %%
Clusters.value_counts()
# Out:
# Clusters
# 2           2526
# 0           1469
# 1              4
# dtype: int64

# %%
df_norm['h_clusterid'] = Clusters
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # K MEANS

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_airline = scaler.fit_transform(Airlines.iloc[:,1:])

# %%
scaled_airline
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
scaled_airline=pd.DataFrame(scaled_airline)
scaled_airline
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10
# ...

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_airline)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
cluster_new = KMeans(4, random_state=42)
cluster_new.fit(scaled_airline)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
cluster_new.labels_
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
Airlines['clusterid_new.labels'] = cluster_new.labels_
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.groupby('clusterid_new.labels').agg(['mean']).reset_index()
# Out:
#   clusterid_new.labels          ID#        Balance  Qual_miles cc1_miles  \
#                                mean           mean        mean      mean
# 0                    0  2245.555073   43563.850375   94.365969  1.215949
# 1                    1  1731.196532  193640.947977  933.589595  2.196532
# 2                    2  1600.001565  116129.633020  136.613459  3.696401
# 3                    3  1664.866667  138061.400000   78.800000  3.466667
#
#   cc2_miles cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo  \
#        mean      mean          mean        mean              mean
# 0  1.019345  1.000395   4646.641532    6.893012        198.932096
# 1  1.034682  1.000000  32098.098266   26.491329       5251.982659
# 2  1.002347  1.001565  38990.929577   18.726135        328.384194
# 3  1.000000  4.066667  93927.866667   28.066667        506.666667
#
#   Flight_trans_12 Days_since_enroll    Award?
#              mean              mean      mean
# ...

# %%
Airlines[Airlines['clusterid_new.labels']==3]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 106    109    96627        1182          1          1          3        49059
# 384    389    28193           0          5          1          4       103456
# 850    861    25629           0          4          1          5       107308
# 904    915    15835           0          2          1          5       112171
# 1036  1047   154664           0          4          1          3        73881
# 1244  1257   166465           0          4          1          4        98717
# 1300  1313   737514           0          3          1          4        43993
# 1878  1895   128302           0          5          1          4       132263
# 1917  1934    82981           0          5          1          3       105325
# 1946  1963   126873           0          4          1          5        95598
# 2251  2269   125679           0          3          1          4        68151
# ...

# %%
Airlines[Airlines['clusterid_new.labels']==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3993  4016     3974           0          1          1          1          365
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines[Airlines['clusterid_new.labels']==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8        9   443003           0          3          2          1         1753
# 21      22   185681        2024          1          1          1        13300
# 42      43    60313           0          1          1          1        10000
# 50      51   108137           0          1          1          1         6368
# 65      66    53914           0          3          1          1        33767
# ...    ...      ...         ...        ...        ...        ...          ...
# 3907  3930   126490           0          1          1          1         8808
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
# 3950  3973    59650           0          1          1          1         5050
#
# ...

# %% [markdown]
# # DBSCAN

# %%
print(Airlines.head())
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    clusterid_new.labels
# 0                     0
# ...

# %%
Airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID#                   3999 non-null   int64
#  1   Balance               3999 non-null   int64
#  2   Qual_miles            3999 non-null   int64
#  3   cc1_miles             3999 non-null   int64
#  4   cc2_miles             3999 non-null   int64
#  5   cc3_miles             3999 non-null   int64
#  6   Bonus_miles           3999 non-null   int64
#  7   Bonus_trans           3999 non-null   int64
#  8   Flight_miles_12mo     3999 non-null   int64
#  9   Flight_trans_12       3999 non-null   int64
#  10  Days_since_enroll     3999 non-null   int64
#  11  Award?                3999 non-null   int64
#  12  clusterid_new.labels  3999 non-null   int32
# dtypes: int32(1), int64(12)
# memory usage: 390.7 KB

# %%
array=Airlines.values
array
# Out:
# array([[    1, 28143,     0, ...,  7000,     0,     0],
#        [    2, 19244,     0, ...,  6968,     0,     0],
#        [    3, 41354,     0, ...,  7034,     0,     0],
#        ...,
#        [ 4019, 73597,     0, ...,  1402,     1,     2],
#        [ 4020, 54899,     0, ...,  1401,     0,     0],
#        [ 4021,  3016,     0, ...,  1398,     0,     0]], dtype=int64)

# %%
Airlines.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
stscaler = StandardScaler().fit(array)
X = stscaler.transform(array)
X=pd.DataFrame(X)
X
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1    -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2    -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3    -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4    -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994  1.725097 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960
# 3995  1.725958 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367
# 3996  1.726820 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804
# 3997  1.727682 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 3998  1.728543 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992
#
#             7         8         9         10        11        12
# ...

# %%
dbscan = DBSCAN(eps=0.8, min_samples=12)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.8, min_samples=12)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
#there are no noise samples
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        1
# 3995        1
# 3996        2
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([Airlines,cl],axis=1)
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...
